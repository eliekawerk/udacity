# %% [markdown]
# Deep Learning
# =============
#
# Assignment 6
# ------------
#
# After training a skip-gram model in `5_word2vec.ipynb`, the goal of this notebook is to train a LSTM character model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  with zipfile.ZipFile(filename) as f:
    name = f.namelist()[0]
    data = tf.compat.as_str(f.read(name))
  return data
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %% [markdown]
# Create a small validation set.

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %% [markdown]
# Utility functions to map characters to vocabulary IDs and back.

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %% [markdown]
# Function to generate a training batch for the LSTM model.

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %% [markdown]
# I always find useful to display the shape or the content of the variables to better understand their structure:

# %%
print(train_batches.next()[1].shape)
print(len(train_text) // batch_size)
print(len(string.ascii_lowercase))
print(np.zeros(shape=(2, 4), dtype=np.float))
# Out:
# (64, 27)
# 1562484
# 26
# [[ 0.  0.  0.  0.]
#  [ 0.  0.  0.  0.]]

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %% [markdown]
# Simple LSTM Model.

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat_v2(outputs, 0), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat_v2(train_labels, 0)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.295595 learning rate: 10.000000
# Minibatch perplexity: 26.99
# ================================================================================
# rhijieasmm ufboam ervecp btxhluyjssyhhej nka eqjp ia   nuaqeix rlnoo qtyagia oee
#  ns os nhdoimgj hpvookytjheonl jlbetcejtnc h g ineoyyofugbippnh psepkcyuskvemail
# uznfgstvd jzrs hx qgm ipukrtnsp ioev chavji ceocovoantvog nf ksnt  o uoevms dzu
# d tkin sbat  eetnwepocliupfkoauhszuji wcmm vhmi royecoetrp s o qrmebqiftx  ecu i
# hkobrpknfeh myaiisqjegeshepse  te  gsipgvleeec xbkv isan  oibjhpyi  ewzodqc eely
# ================================================================================
# Validation set perplexity: 19.94
# Average loss at step 100: 2.588819 learning rate: 10.000000
# Minibatch perplexity: 10.12
# Validation set perplexity: 10.89
# Average loss at step 200: 2.256279 learning rate: 10.000000
# Minibatch perplexity: 9.64
# Validation set perplexity: 9.14
# Average loss at step 300: 2.098950 learning rate: 10.000000
# Minibatch perplexity: 7.68
# Validation set perplexity: 7.93
# Average loss at step 400: 1.999093 learning rate: 10.000000
# Minibatch perplexity: 7.52
# Validation set perplexity: 7.54
# Average loss at step 500: 1.931182 learning rate: 10.000000
# Minibatch perplexity: 6.25
# Validation set perplexity: 7.06
# Average loss at step 600: 1.904067 learning rate: 10.000000
# Minibatch perplexity: 6.27
# Validation set perplexity: 6.71
# Average loss at step 700: 1.857449 learning rate: 10.000000
# Minibatch perplexity: 5.54
# Validation set perplexity: 6.61
# Average loss at step 800: 1.822658 learning rate: 10.000000
# Minibatch perplexity: 6.08
# Validation set perplexity: 6.56
# Average loss at step 900: 1.831078 learning rate: 10.000000
# Minibatch perplexity: 7.24
# Validation set perplexity: 6.23
# Average loss at step 1000: 1.824351 learning rate: 10.000000
# Minibatch perplexity: 5.93
# ================================================================================
# aris notations d intrument were pirder is certs in the veralling biolgn differen
# by pixts in amurreptay un adcest akaves engiy poce diblisis incaposoditing histe
# atial beodicctive was nay and force the singly dinist be the vicanuathived chiss
# ula in a forktign froces avopation plas itirestip ylisted div one two slecetbers
# vewiced cefforing mps serament they pecriknia hin lons he forthorical six araua
# ================================================================================
# Validation set perplexity: 6.13
# Average loss at step 1100: 1.776435 learning rate: 10.000000
# Minibatch perplexity: 5.62
# Validation set perplexity: 5.89
# Average loss at step 1200: 1.753099 learning rate: 10.000000
# Minibatch perplexity: 6.06
# Validation set perplexity: 5.67
# Average loss at step 1300: 1.733647 learning rate: 10.000000
# Minibatch perplexity: 5.87
# Validation set perplexity: 5.69
# Average loss at step 1400: 1.746831 learning rate: 10.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 5.54
# Average loss at step 1500: 1.741256 learning rate: 10.000000
# Minibatch perplexity: 6.30
# Validation set perplexity: 5.49
# Average loss at step 1600: 1.749779 learning rate: 10.000000
# Minibatch perplexity: 5.14
# Validation set perplexity: 5.37
# Average loss at step 1700: 1.712843 learning rate: 10.000000
# Minibatch perplexity: 4.52
# Validation set perplexity: 5.38
# Average loss at step 1800: 1.676488 learning rate: 10.000000
# Minibatch perplexity: 4.93
# Validation set perplexity: 5.23
# Average loss at step 1900: 1.651914 learning rate: 10.000000
# Minibatch perplexity: 5.94
# Validation set perplexity: 5.30
# Average loss at step 2000: 1.699875 learning rate: 10.000000
# Minibatch perplexity: 4.93
# ================================================================================
# fines the unit is three four one nine five infinity productimate one nine eight
# fifity frence inchirsball keaminish mimmety im chast ang oacres of the set have
# disict of exited the polac spevel of jeference bighth comment in and writp dii i
# chet of the unities polieer of the rulen is three nine nine three three zero fou
# en zero ed the he zero s s givs ctrist the polits joled cominity not ngize amout
# ================================================================================
# Validation set perplexity: 5.13
# Average loss at step 2100: 1.692097 learning rate: 10.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 4.90
# Average loss at step 2200: 1.685066 learning rate: 10.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 5.08
# Average loss at step 2300: 1.648408 learning rate: 10.000000
# Minibatch perplexity: 5.72
# Validation set perplexity: 4.93
# Average loss at step 2400: 1.663060 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 4.84
# Average loss at step 2500: 1.680168 learning rate: 10.000000
# Minibatch perplexity: 5.84
# Validation set perplexity: 4.69
# Average loss at step 2600: 1.656970 learning rate: 10.000000
# Minibatch perplexity: 5.61
# Validation set perplexity: 4.68
# Average loss at step 2700: 1.661133 learning rate: 10.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 4.68
# Average loss at step 2800: 1.652030 learning rate: 10.000000
# Minibatch perplexity: 4.84
# Validation set perplexity: 4.49
# Average loss at step 2900: 1.654393 learning rate: 10.000000
# Minibatch perplexity: 4.51
# Validation set perplexity: 4.51
# Average loss at step 3000: 1.654200 learning rate: 10.000000
# Minibatch perplexity: 4.91
# ================================================================================
# dian sympaning distriau beight sconsion on the isporist througe open and ruplest
# x imactions and russe and armedly and soutis stull in on the enaten schon sathri
# query noted two zoring pentra partrandan papinkbuid with pater are troukhed has
# vattim medic breek go him as inter with to big hame namorns lindreschose was dic
# dended what now sourry has inwine martant and tabling and election and tratfil e
# ================================================================================
# Validation set perplexity: 4.64
# Average loss at step 3100: 1.634767 learning rate: 10.000000
# Minibatch perplexity: 5.76
# Validation set perplexity: 4.67
# Average loss at step 3200: 1.652355 learning rate: 10.000000
# Minibatch perplexity: 4.93
# Validation set perplexity: 4.59
# Average loss at step 3300: 1.641140 learning rate: 10.000000
# Minibatch perplexity: 5.94
# Validation set perplexity: 4.54
# Average loss at step 3400: 1.674861 learning rate: 10.000000
# Minibatch perplexity: 6.43
# Validation set perplexity: 4.55
# Average loss at step 3500: 1.658120 learning rate: 10.000000
# Minibatch perplexity: 5.74
# Validation set perplexity: 4.69
# Average loss at step 3600: 1.669641 learning rate: 10.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.51
# Average loss at step 3700: 1.648183 learning rate: 10.000000
# Minibatch perplexity: 5.45
# Validation set perplexity: 4.54
# Average loss at step 3800: 1.646815 learning rate: 10.000000
# Minibatch perplexity: 4.63
# Validation set perplexity: 4.56
# Average loss at step 3900: 1.640333 learning rate: 10.000000
# Minibatch perplexity: 5.87
# Validation set perplexity: 4.59
# Average loss at step 4000: 1.652747 learning rate: 10.000000
# Minibatch perplexity: 4.73
# ================================================================================
# jlitar latake of the longing awrialized in or drith he brita and ross defessiona
# chates in scetyly rocura sole he searchist of ralist fund smymeate georson equev
# jects even an otrung takan eague of one nine six six one eight one four x one ni
# white he wheid l extet alliemical medelam cossedise fronporabe in grack ales the
# terial zero one six zero zero zero nine proca bytaine shorter cope javal celvain
# ================================================================================
# Validation set perplexity: 4.53
# Average loss at step 4100: 1.636340 learning rate: 10.000000
# Minibatch perplexity: 5.45
# Validation set perplexity: 4.70
# Average loss at step 4200: 1.639927 learning rate: 10.000000
# Minibatch perplexity: 4.88
# Validation set perplexity: 4.41
# Average loss at step 4300: 1.618071 learning rate: 10.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 4.39
# Average loss at step 4400: 1.611017 learning rate: 10.000000
# Minibatch perplexity: 4.93
# Validation set perplexity: 4.38
# Average loss at step 4500: 1.620160 learning rate: 10.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 4.51
# Average loss at step 4600: 1.615988 learning rate: 10.000000
# Minibatch perplexity: 5.18
# Validation set perplexity: 4.48
# Average loss at step 4700: 1.628308 learning rate: 10.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 4.50
# Average loss at step 4800: 1.629773 learning rate: 10.000000
# Minibatch perplexity: 4.96
# Validation set perplexity: 4.46
# Average loss at step 4900: 1.635506 learning rate: 10.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 4.59
# Average loss at step 5000: 1.608740 learning rate: 1.000000
# Minibatch perplexity: 5.32
# ================================================================================
# tion of suravents to beadical or nine mytys penall six br relooces he has air at
# s given is about of climil to activitily discan ceotel plant or smockent is hiac
# blish of shicly to one nine six eight m one eight nine six two one nine nine thr
# ply listed in before rossic providon a not prophylistifism esterts was a videres
# les s the was naturase manded frostwhonotaning these muse haslono the logitary f
# ================================================================================
# Validation set perplexity: 4.48
# Average loss at step 5100: 1.604848 learning rate: 1.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 4.34
# Average loss at step 5200: 1.592210 learning rate: 1.000000
# Minibatch perplexity: 4.55
# Validation set perplexity: 4.29
# Average loss at step 5300: 1.580233 learning rate: 1.000000
# Minibatch perplexity: 5.44
# Validation set perplexity: 4.24
# Average loss at step 5400: 1.580518 learning rate: 1.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 4.24
# Average loss at step 5500: 1.571477 learning rate: 1.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 4.24
# Average loss at step 5600: 1.586992 learning rate: 1.000000
# Minibatch perplexity: 4.91
# Validation set perplexity: 4.27
# Average loss at step 5700: 1.568927 learning rate: 1.000000
# Minibatch perplexity: 4.64
# Validation set perplexity: 4.25
# Average loss at step 5800: 1.583257 learning rate: 1.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 4.26
# Average loss at step 5900: 1.575594 learning rate: 1.000000
# Minibatch perplexity: 4.59
# Validation set perplexity: 4.27
# Average loss at step 6000: 1.544568 learning rate: 1.000000
# Minibatch perplexity: 4.88
# ================================================================================
# boy sencia at most formation of seem suba sonsiglent one nine two arly becomes a
# jefor kindgn some trantia unrio germanaly the propon thay varh autism the the u
# arhy sef b s c first the wodunk struinsial became mpal fold esecting hi sagev ge
# juch can projood year sex five evaty shege nom relative equals tadins which seve
# oud high incount stative tounaled christed the dender thirguadai orperial any bo
# ================================================================================
# Validation set perplexity: 4.26
# Average loss at step 6100: 1.564986 learning rate: 1.000000
# Minibatch perplexity: 4.14
# Validation set perplexity: 4.25
# Average loss at step 6200: 1.537971 learning rate: 1.000000
# Minibatch perplexity: 5.36
# Validation set perplexity: 4.22
# Average loss at step 6300: 1.547079 learning rate: 1.000000
# Minibatch perplexity: 4.63
# Validation set perplexity: 4.21
# Average loss at step 6400: 1.544576 learning rate: 1.000000
# Minibatch perplexity: 4.99
# Validation set perplexity: 4.22
# Average loss at step 6500: 1.559817 learning rate: 1.000000
# Minibatch perplexity: 4.73
# Validation set perplexity: 4.23
# Average loss at step 6600: 1.595470 learning rate: 1.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 4.21
# Average loss at step 6700: 1.581934 learning rate: 1.000000
# Minibatch perplexity: 4.56
# Validation set perplexity: 4.23
# Average loss at step 6800: 1.606693 learning rate: 1.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 4.23
# Average loss at step 6900: 1.584373 learning rate: 1.000000
# Minibatch perplexity: 4.59
# Validation set perplexity: 4.26
# Average loss at step 7000: 1.581197 learning rate: 1.000000
# Minibatch perplexity: 4.73
# ================================================================================
# march aur evidengle ruth to the lenlure gailly meanibition that avilsis uns ruth
# ugp used cowordious their contiverse with unsters cailam as to marthely obtymati
# zerou s a crimation statical because of slas on the el rogence mark colmens air
# to pailts pittening been f kings cat and masity in the ypas intelling of to houg
# ce planoe chang of one seven areat modern with one nine sto souption and cervers
# ================================================================================
# Validation set perplexity: 4.23

# %% [markdown]
# ---
# Problem 1
# ---------
#
# You might have noticed that the definition of the LSTM cell involves 4 matrix multiplications with the input, and 4 matrix multiplications with the output. Simplify the expression by using a single matrix multiply for each, and variables that are 4 times larger.
#
# ---

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Concatenate parameters  
  sx = tf.concat(1, [ix, fx, cx, ox])
  sm = tf.concat(1, [im, fm, cm, om])
  sb = tf.concat(1, [ib, fb, cb, ob])
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    smatmul = tf.matmul(i, sx) + tf.matmul(o, sm) + sb
    smatmul_input, smatmul_forget, update, smatmul_output = tf.split(1, 4, smatmul)
    input_gate = tf.sigmoid(smatmul_input)
    forget_gate = tf.sigmoid(smatmul_forget)
    output_gate = tf.sigmoid(smatmul_output)
    #input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    #forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    #update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    #output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.294986 learning rate: 10.000000
# Minibatch perplexity: 26.98
# ================================================================================
# pntush odvpv piirhsnhp ieafwdovzogsi ryghgeyaovofgnpwuev kpepyemsmkzoignfd   qts
# hbin t ele lnbybhaairfsxret ablt rlreot cqjdiseqfieusnxarwreoekzyenxeypdsinq ano
# uxoopn bdq xgreiwp ashscrlrvnl il ippxab lo bdjdhcevwdnmzcm eo xtnmuva hidndzhlw
# rmnnfugomqnykeorzfsehotgqeeo owdu eqrhy eyan rgumktvpa rs  oysaazetwzt ces dz wc
# nrs dpsrdlxat svhaid vfpfdfnmiatoaveq reec ka htne qebrior ioavilmuedqax qwcx ra
# ================================================================================
# Validation set perplexity: 20.12
# Average loss at step 100: 2.595044 learning rate: 10.000000
# Minibatch perplexity: 11.02
# Validation set perplexity: 10.59
# Average loss at step 200: 2.272315 learning rate: 10.000000
# Minibatch perplexity: 8.56
# Validation set perplexity: 8.85
# Average loss at step 300: 2.115343 learning rate: 10.000000
# Minibatch perplexity: 7.60
# Validation set perplexity: 8.21
# Average loss at step 400: 1.992986 learning rate: 10.000000
# Minibatch perplexity: 7.58
# Validation set perplexity: 7.46
# Average loss at step 500: 1.959514 learning rate: 10.000000
# Minibatch perplexity: 6.75
# Validation set perplexity: 7.06
# Average loss at step 600: 1.931658 learning rate: 10.000000
# Minibatch perplexity: 7.28
# Validation set perplexity: 6.87
# Average loss at step 700: 1.892533 learning rate: 10.000000
# Minibatch perplexity: 5.92
# Validation set perplexity: 6.83
# Average loss at step 800: 1.886903 learning rate: 10.000000
# Minibatch perplexity: 5.86
# Validation set perplexity: 6.67
# Average loss at step 900: 1.833958 learning rate: 10.000000
# Minibatch perplexity: 5.70
# Validation set perplexity: 6.37
# Average loss at step 1000: 1.809359 learning rate: 10.000000
# Minibatch perplexity: 6.57
# ================================================================================
# cyored hurson are froms which gick and presuerite led air free am artiblats and
# er sume nem of respeadination with lophestine depay of prinine bromavla one nati
# val the of when wrize of a sapessia crease ic indipallo was deserbour agrien it
# z the ground the one smaces radette mankurters or grizglitn rungitism pub fourds
# zer seame brang when curner ristited mech with that air vere the one four five t
# ================================================================================
# Validation set perplexity: 6.21
# Average loss at step 1100: 1.786711 learning rate: 10.000000
# Minibatch perplexity: 5.56
# Validation set perplexity: 6.25
# Average loss at step 1200: 1.791898 learning rate: 10.000000
# Minibatch perplexity: 5.83
# Validation set perplexity: 5.83
# Average loss at step 1300: 1.756893 learning rate: 10.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 5.95
# Average loss at step 1400: 1.752745 learning rate: 10.000000
# Minibatch perplexity: 6.02
# Validation set perplexity: 5.81
# Average loss at step 1500: 1.727673 learning rate: 10.000000
# Minibatch perplexity: 6.16
# Validation set perplexity: 5.71
# Average loss at step 1600: 1.714772 learning rate: 10.000000
# Minibatch perplexity: 6.08
# Validation set perplexity: 5.55
# Average loss at step 1700: 1.711405 learning rate: 10.000000
# Minibatch perplexity: 5.65
# Validation set perplexity: 5.56
# Average loss at step 1800: 1.687531 learning rate: 10.000000
# Minibatch perplexity: 5.45
# Validation set perplexity: 5.54
# Average loss at step 1900: 1.704316 learning rate: 10.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 5.30
# Average loss at step 2000: 1.720498 learning rate: 10.000000
# Minibatch perplexity: 5.80
# ================================================================================
# deffection brouse the iden boys or didensing the schen in artific eflactly easib
# quarby of strodeint eight then of mike fully the eagane esiol deferench amarally
# x at hig mried othe is zero or edernces orly was of clairces was breaters them o
# atory an resages deasever or playe the colen ex abolcene namas lisser ances semb
# vensed in existe a three ack to need an orseft of edatary combery apcembes the o
# ================================================================================
# Validation set perplexity: 5.22
# Average loss at step 2100: 1.710303 learning rate: 10.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 5.28
# Average loss at step 2200: 1.689799 learning rate: 10.000000
# Minibatch perplexity: 5.42
# Validation set perplexity: 5.23
# Average loss at step 2300: 1.692317 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 5.21
# Average loss at step 2400: 1.689907 learning rate: 10.000000
# Minibatch perplexity: 5.58
# Validation set perplexity: 5.17
# Average loss at step 2500: 1.689576 learning rate: 10.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 5.12
# Average loss at step 2600: 1.683449 learning rate: 10.000000
# Minibatch perplexity: 5.76
# Validation set perplexity: 5.43
# Average loss at step 2700: 1.680807 learning rate: 10.000000
# Minibatch perplexity: 5.04
# Validation set perplexity: 5.20
# Average loss at step 2800: 1.682071 learning rate: 10.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 5.14
# Average loss at step 2900: 1.658234 learning rate: 10.000000
# Minibatch perplexity: 5.31
# Validation set perplexity: 5.05
# Average loss at step 3000: 1.640134 learning rate: 10.000000
# Minibatch perplexity: 5.96
# ================================================================================
# or nfith confullef through averssre word callet radeped micdsconers they as to t
# anwes in one one youndi y c i momayoners lonus aul ess c berease byamolar cantve
# s nine four eight thr emcopes the stuction sis store eive signif damonthly of yo
# bint for a chisal usiackrome mathle or towara more a detist or lendilized is off
# the see stronsized as the resix aggincrisers irel withn of hohar was he as was t
# ================================================================================
# Validation set perplexity: 5.05
# Average loss at step 3100: 1.637468 learning rate: 10.000000
# Minibatch perplexity: 4.81
# Validation set perplexity: 4.92
# Average loss at step 3200: 1.641682 learning rate: 10.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 5.11
# Average loss at step 3300: 1.683514 learning rate: 10.000000
# Minibatch perplexity: 5.05
# Validation set perplexity: 5.04
# Average loss at step 3400: 1.652238 learning rate: 10.000000
# Minibatch perplexity: 4.57
# Validation set perplexity: 4.94
# Average loss at step 3500: 1.655489 learning rate: 10.000000
# Minibatch perplexity: 4.27
# Validation set perplexity: 4.94
# Average loss at step 3600: 1.660444 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 4.79
# Average loss at step 3700: 1.655852 learning rate: 10.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 4.90
# Average loss at step 3800: 1.635994 learning rate: 10.000000
# Minibatch perplexity: 5.04
# Validation set perplexity: 4.77
# Average loss at step 3900: 1.619363 learning rate: 10.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 4.72
# Average loss at step 4000: 1.610956 learning rate: 10.000000
# Minibatch perplexity: 4.50
# ================================================================================
# kanat bein a states invisented universe order lihtes in one eight poliman martox
# becally traineter jononst b even marinan deviden fail d jame tass with the revar
#  and sauls for myron and it leiting in deleas jamoned ostabuint bet esticiances
# by integral hoding to the and gentang controlled of includeloar swew or the a ch
# varianal ecoos largemon stold view main azik gamance one nine eight nine tabeenc
# ================================================================================
# Validation set perplexity: 4.89
# Average loss at step 4100: 1.627429 learning rate: 10.000000
# Minibatch perplexity: 5.33
# Validation set perplexity: 4.91
# Average loss at step 4200: 1.619577 learning rate: 10.000000
# Minibatch perplexity: 4.55
# Validation set perplexity: 4.83
# Average loss at step 4300: 1.633185 learning rate: 10.000000
# Minibatch perplexity: 4.63
# Validation set perplexity: 5.14
# Average loss at step 4400: 1.620049 learning rate: 10.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 4.92
# Average loss at step 4500: 1.624198 learning rate: 10.000000
# Minibatch perplexity: 4.55
# Validation set perplexity: 4.85
# Average loss at step 4600: 1.616691 learning rate: 10.000000
# Minibatch perplexity: 5.39
# Validation set perplexity: 4.90
# Average loss at step 4700: 1.615891 learning rate: 10.000000
# Minibatch perplexity: 4.89
# Validation set perplexity: 4.86
# Average loss at step 4800: 1.614021 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 4.96
# Average loss at step 4900: 1.606479 learning rate: 10.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 4.84
# Average loss at step 5000: 1.616135 learning rate: 1.000000
# Minibatch perplexity: 4.93
# ================================================================================
# zeror mover of he nance highed a mocement yoata s e one nine six zero doh s scri
# an sound of metnow or majir reims tuns three lifficianed and spack gratt hambed
# t or one three quews signist autonom have provisited one nine thon three one and
# maghishs and ato manists ef persy him the common or original towns and  common o
# one was s that hed internay some percraved wiblt whitelly by the herree has s a
# ================================================================================
# Validation set perplexity: 5.04
# Average loss at step 5100: 1.606444 learning rate: 1.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 4.84
# Average loss at step 5200: 1.589186 learning rate: 1.000000
# Minibatch perplexity: 4.58
# Validation set perplexity: 4.73
# Average loss at step 5300: 1.590544 learning rate: 1.000000
# Minibatch perplexity: 4.60
# Validation set perplexity: 4.69
# Average loss at step 5400: 1.572799 learning rate: 1.000000
# Minibatch perplexity: 5.62
# Validation set perplexity: 4.62
# Average loss at step 5500: 1.577823 learning rate: 1.000000
# Minibatch perplexity: 4.50
# Validation set perplexity: 4.56
# Average loss at step 5600: 1.602672 learning rate: 1.000000
# Minibatch perplexity: 4.76
# Validation set perplexity: 4.59
# Average loss at step 5700: 1.574597 learning rate: 1.000000
# Minibatch perplexity: 5.78
# Validation set perplexity: 4.59
# Average loss at step 5800: 1.583465 learning rate: 1.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 4.57
# Average loss at step 5900: 1.573016 learning rate: 1.000000
# Minibatch perplexity: 4.13
# Validation set perplexity: 4.61
# Average loss at step 6000: 1.581558 learning rate: 1.000000
# Minibatch perplexity: 4.79
# ================================================================================
# jase dakes with april time a indoougen were former werens and back one nine eigh
# y comsips armor wastial offigial it y stor k son s may sninto faced condection d
# hip seven three the muther electrans in talf scriptional ussporated livervocatio
# et scienal as trainer histeated overat the jodlu disalenner are asfirt first the
# shoran forms dysense some emperizate on the seal bave suce is him the torabinati
# ================================================================================
# Validation set perplexity: 4.60
# Average loss at step 6100: 1.584218 learning rate: 1.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 4.63
# Average loss at step 6200: 1.568780 learning rate: 1.000000
# Minibatch perplexity: 4.30
# Validation set perplexity: 4.67
# Average loss at step 6300: 1.557155 learning rate: 1.000000
# Minibatch perplexity: 4.61
# Validation set perplexity: 4.66
# Average loss at step 6400: 1.603906 learning rate: 1.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 4.63
# Average loss at step 6500: 1.565521 learning rate: 1.000000
# Minibatch perplexity: 4.93
# Validation set perplexity: 4.63
# Average loss at step 6600: 1.586595 learning rate: 1.000000
# Minibatch perplexity: 4.59
# Validation set perplexity: 4.67
# Average loss at step 6700: 1.565962 learning rate: 1.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 4.59
# Average loss at step 6800: 1.590505 learning rate: 1.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.57
# Average loss at step 6900: 1.602828 learning rate: 1.000000
# Minibatch perplexity: 4.46
# Validation set perplexity: 4.55
# Average loss at step 7000: 1.550569 learning rate: 1.000000
# Minibatch perplexity: 4.45
# ================================================================================
# way two and similar sulerlorn is globaligy including side examples sheer the fir
# lost sateiduly arrieb riple view often madie then meachel glijerit he shefique p
# thing for attanisties as in just of out from a pub repartiors it which frenchaga
# chken militars bassini one time for a fod a clown one one uguaids was after for
# nacts have the manckiase pagan in one nine nine marking mographite for a immeme
# ================================================================================
# Validation set perplexity: 4.57

# %% [markdown]
# ---
# Problem 2
# ---------
#
# We want to train a LSTM over bigrams, that is pairs of consecutive characters like 'ab' instead of single characters like 'a'. Since the number of possible bigrams is large, feeding them directly to the LSTM using 1-hot encodings will lead to a very sparse representation that is very wasteful computationally.
#
# a- Introduce an embedding lookup on the inputs, and feed the embeddings to the LSTM cell instead of the inputs themselves.
#
# b- Write a bigram-based LSTM, modeled on the character LSTM above.
#
# c- Introduce Dropout. For best practices on how to use Dropout in LSTMs, refer to this [article](http://arxiv.org/abs/1409.2329).
#
# ---

# %% [markdown]
# Let's first adapt the LSTM for a single character input with embeddings. The feed_dict is unchanged, the embeddings are looked up from the inputs. Note that the output is an array probability for the possible characters, not an embedding.

# %%
embedding_size = 128 # Dimension of the embedding vector.
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  vocabulary_embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    i_embed = tf.nn.embedding_lookup(vocabulary_embeddings, tf.argmax(i, dimension=1))
    output, state = lstm_cell(i_embed, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  sample_input_embedding = tf.nn.embedding_lookup(vocabulary_embeddings, tf.argmax(sample_input, dimension=1))
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input_embedding, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.307029 learning rate: 10.000000
# Minibatch perplexity: 27.30
# ================================================================================
# p rq uphoqlwpwinj h rp gq  tyeu idrlnbt ncz uonie tecihvr k meo  qn zt rtichgoor
# rloejpohosnreu nfetdfnjcwad o   honynene   unrttvq d ei u fiw anapodtn cqbxem av
# vhridkcrekeemvi m hkjue msr  tiofmnchtdsevskyn kneesal ybgvq ensano eecl ieino
# zavchbderbepf tldgeewo ajna bk nhe tvclcel bhm gns rwtkanku ate v fm o nluo o tb
# qsvtctwgpedinnaulo t nterfvgrcy iipspeizqc ruhfteo te  qrgpo nvt  uishc ipkgxdr
# ================================================================================
# Validation set perplexity: 19.32
# Average loss at step 100: 2.260012 learning rate: 10.000000
# Minibatch perplexity: 7.35
# Validation set perplexity: 8.83
# Average loss at step 200: 2.028017 learning rate: 10.000000
# Minibatch perplexity: 7.79
# Validation set perplexity: 7.46
# Average loss at step 300: 1.968683 learning rate: 10.000000
# Minibatch perplexity: 6.60
# Validation set perplexity: 7.06
# Average loss at step 400: 1.892411 learning rate: 10.000000
# Minibatch perplexity: 6.44
# Validation set perplexity: 6.44
# Average loss at step 500: 1.859793 learning rate: 10.000000
# Minibatch perplexity: 5.94
# Validation set perplexity: 6.63
# Average loss at step 600: 1.843533 learning rate: 10.000000
# Minibatch perplexity: 6.13
# Validation set perplexity: 6.24
# Average loss at step 700: 1.813021 learning rate: 10.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 5.92
# Average loss at step 800: 1.741237 learning rate: 10.000000
# Minibatch perplexity: 5.56
# Validation set perplexity: 6.03
# Average loss at step 900: 1.751438 learning rate: 10.000000
# Minibatch perplexity: 5.67
# Validation set perplexity: 5.88
# Average loss at step 1000: 1.757287 learning rate: 10.000000
# Minibatch perplexity: 5.65
# ================================================================================
# als that with chardio it airs gordn ditawition won wirds a chardmananotials tati
# e stidied domost in the attural disfrecs of several iranuag is that a boox was c
#  romon may some distremid ronso arcomes s raid of intents ultion arelished press
# formich of sollets the the palas comsie to forcial of hige four mattenn mebrenco
# ne promoks so s lraities two chreaistorbadly canning bun gaments dewalls laborg
# ================================================================================
# Validation set perplexity: 5.70
# Average loss at step 1100: 1.737571 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 5.66
# Average loss at step 1200: 1.708035 learning rate: 10.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 5.57
# Average loss at step 1300: 1.698111 learning rate: 10.000000
# Minibatch perplexity: 4.82
# Validation set perplexity: 5.73
# Average loss at step 1400: 1.702356 learning rate: 10.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 5.58
# Average loss at step 1500: 1.728807 learning rate: 10.000000
# Minibatch perplexity: 5.92
# Validation set perplexity: 5.29
# Average loss at step 1600: 1.691394 learning rate: 10.000000
# Minibatch perplexity: 5.63
# Validation set perplexity: 5.27
# Average loss at step 1700: 1.685065 learning rate: 10.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 5.41
# Average loss at step 1800: 1.706139 learning rate: 10.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 5.53
# Average loss at step 1900: 1.686647 learning rate: 10.000000
# Minibatch perplexity: 5.22
# Validation set perplexity: 5.50
# Average loss at step 2000: 1.663334 learning rate: 10.000000
# Minibatch perplexity: 4.67
# ================================================================================
# drogh bards invol of the sarthled of lational cnects where novertys tanss blerat
# gi allect of idendence in cate b priety formeas cdonossion raic from entles eigh
# farts partaindest monarted collity groul the two eight he zero three cale tread
# stry publication vaided pocel airn in these in the eight force ap wone opery at
# ner to gardayer propsion ofndett medition of three zero seven wikhnizing but of
# ================================================================================
# Validation set perplexity: 5.07
# Average loss at step 2100: 1.666205 learning rate: 10.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 5.27
# Average loss at step 2200: 1.692379 learning rate: 10.000000
# Minibatch perplexity: 5.96
# Validation set perplexity: 5.18
# Average loss at step 2300: 1.690794 learning rate: 10.000000
# Minibatch perplexity: 4.44
# Validation set perplexity: 5.27
# Average loss at step 2400: 1.678948 learning rate: 10.000000
# Minibatch perplexity: 5.89
# Validation set perplexity: 5.10
# Average loss at step 2500: 1.675863 learning rate: 10.000000
# Minibatch perplexity: 5.27
# Validation set perplexity: 5.15
# Average loss at step 2600: 1.653388 learning rate: 10.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 5.20
# Average loss at step 2700: 1.652594 learning rate: 10.000000
# Minibatch perplexity: 5.73
# Validation set perplexity: 5.07
# Average loss at step 2800: 1.661067 learning rate: 10.000000
# Minibatch perplexity: 5.38
# Validation set perplexity: 4.82
# Average loss at step 2900: 1.649089 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 4.92
# Average loss at step 3000: 1.658481 learning rate: 10.000000
# Minibatch perplexity: 5.35
# ================================================================================
# jack more kennag of the eaylw lectural out lithuanal come mostrical one nine sis
# ounte actor ut the linke empan the ween grailing assouctions the noulv as u mos
# cept the warter of andiable often the retey into evolors ways one five six two z
# agless exampet is in the came levice and m eight of the his at tita pars reforme
#  which known the isumble of hine two at eight nine eight zero againt the maocita
# ================================================================================
# Validation set perplexity: 5.14
# Average loss at step 3100: 1.645112 learning rate: 10.000000
# Minibatch perplexity: 5.67
# Validation set perplexity: 5.00
# Average loss at step 3200: 1.638240 learning rate: 10.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 5.06
# Average loss at step 3300: 1.628126 learning rate: 10.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 5.10
# Average loss at step 3400: 1.640329 learning rate: 10.000000
# Minibatch perplexity: 4.80
# Validation set perplexity: 4.99
# Average loss at step 3500: 1.638863 learning rate: 10.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 5.10
# Average loss at step 3600: 1.628378 learning rate: 10.000000
# Minibatch perplexity: 5.20
# Validation set perplexity: 5.01
# Average loss at step 3700: 1.622100 learning rate: 10.000000
# Minibatch perplexity: 4.62
# Validation set perplexity: 5.15
# Average loss at step 3800: 1.630929 learning rate: 10.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 5.05
# Average loss at step 3900: 1.633173 learning rate: 10.000000
# Minibatch perplexity: 5.01
# Validation set perplexity: 5.06
# Average loss at step 4000: 1.612921 learning rate: 10.000000
# Minibatch perplexity: 4.69
# ================================================================================
# veilstral in the his crict cur blocked to designestn stil s europic the cuscry a
# x special banabliner in cased to charritaster the  one seven sequal sb islic and
# but cuburoses included refera most and caster an ruler the playoties discolity d
# jue off law histor field bassa one eight four s alyhylon provides extended to a
# or known for mmast and such s or lince candou kriventic the free withly pad one
# ================================================================================
# Validation set perplexity: 5.05
# Average loss at step 4100: 1.599116 learning rate: 10.000000
# Minibatch perplexity: 4.88
# Validation set perplexity: 5.09
# Average loss at step 4200: 1.649675 learning rate: 10.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 5.19
# Average loss at step 4300: 1.645095 learning rate: 10.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 4.91
# Average loss at step 4400: 1.631891 learning rate: 10.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 5.02
# Average loss at step 4500: 1.617482 learning rate: 10.000000
# Minibatch perplexity: 5.39
# Validation set perplexity: 5.20
# Average loss at step 4600: 1.605014 learning rate: 10.000000
# Minibatch perplexity: 5.44
# Validation set perplexity: 5.23
# Average loss at step 4700: 1.621195 learning rate: 10.000000
# Minibatch perplexity: 5.48
# Validation set perplexity: 5.24
# Average loss at step 4800: 1.643069 learning rate: 10.000000
# Minibatch perplexity: 5.97
# Validation set perplexity: 5.11
# Average loss at step 4900: 1.652980 learning rate: 10.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 4.95
# Average loss at step 5000: 1.650222 learning rate: 1.000000
# Minibatch perplexity: 5.44
# ================================================================================
# kn the fead starlitical to ecospia annus one zero zero c or modation helsinnard
# cks this can islanned itask s nany from the of eachnirks in the freopean of call
# numanisl in elections of a cequllo by one nine eight five the giantan after thre
# kistil in and arts moding with the all spontic ansu coloxy otwo selfyselysaus i
# ketting tvbolinbosed en languagetining be arran est mirth tourwarli minde denira
# ================================================================================
# Validation set perplexity: 4.83
# Average loss at step 5100: 1.594617 learning rate: 1.000000
# Minibatch perplexity: 4.70
# Validation set perplexity: 4.62
# Average loss at step 5200: 1.573761 learning rate: 1.000000
# Minibatch perplexity: 4.89
# Validation set perplexity: 4.62
# Average loss at step 5300: 1.562510 learning rate: 1.000000
# Minibatch perplexity: 4.73
# Validation set perplexity: 4.60
# Average loss at step 5400: 1.594293 learning rate: 1.000000
# Minibatch perplexity: 4.89
# Validation set perplexity: 4.60
# Average loss at step 5500: 1.551098 learning rate: 1.000000
# Minibatch perplexity: 4.81
# Validation set perplexity: 4.56
# Average loss at step 5600: 1.558331 learning rate: 1.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 4.56
# Average loss at step 5700: 1.555761 learning rate: 1.000000
# Minibatch perplexity: 4.36
# Validation set perplexity: 4.57
# Average loss at step 5800: 1.548051 learning rate: 1.000000
# Minibatch perplexity: 4.19
# Validation set perplexity: 4.61
# Average loss at step 5900: 1.562186 learning rate: 1.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.58
# Average loss at step 6000: 1.578169 learning rate: 1.000000
# Minibatch perplexity: 4.43
# ================================================================================
# que time obtractions from the property finite majory to four nine nine k pugrant
# h famting their new schour of as the tender bomber table of nit major spect many
# leger state touroms adambothyldel passal were chinotherdom wood the limit centra
# wael by k sayet or life wavfer b wslald to worded on bases metery horish in indv
# tow as the are lave rong but chetba was changedy anrounds kelp in ong slutions c
# ================================================================================
# Validation set perplexity: 4.58
# Average loss at step 6100: 1.603845 learning rate: 1.000000
# Minibatch perplexity: 5.53
# Validation set perplexity: 4.58
# Average loss at step 6200: 1.609249 learning rate: 1.000000
# Minibatch perplexity: 4.40
# Validation set perplexity: 4.47
# Average loss at step 6300: 1.624552 learning rate: 1.000000
# Minibatch perplexity: 4.54
# Validation set perplexity: 4.48
# Average loss at step 6400: 1.578730 learning rate: 1.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 4.48
# Average loss at step 6500: 1.583510 learning rate: 1.000000
# Minibatch perplexity: 5.36
# Validation set perplexity: 4.51
# Average loss at step 6600: 1.546479 learning rate: 1.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 4.51
# Average loss at step 6700: 1.554795 learning rate: 1.000000
# Minibatch perplexity: 4.76
# Validation set perplexity: 4.47
# Average loss at step 6800: 1.558125 learning rate: 1.000000
# Minibatch perplexity: 4.82
# Validation set perplexity: 4.48
# Average loss at step 6900: 1.540450 learning rate: 1.000000
# Minibatch perplexity: 5.83
# Validation set perplexity: 4.46
# Average loss at step 7000: 1.583561 learning rate: 1.000000
# Minibatch perplexity: 5.14
# ================================================================================
# gn locative by a wiho which nake also held uppetion to bord march day westry and
# her occ list alosumple in theil dos tox versian interfeal drowneral louism ambol
# mics accepent was christita zero the complegember theory ana buslo of thems of w
# way bothing he on the recurvematis graphically tries and of one nine nine throug
# radu singer to acciction vaille eet boy the cities bucur have two eight zero thr
# ================================================================================
# Validation set perplexity: 4.41

# %% [markdown]
# We can now use bigrams as inputs for the training. Here again, the feed_dict is unchanged, the bigram embeddings are looked up from the inputs. The output of the LSTM is still a probability array of the possible characters (not bigrams).

# %%
embedding_size = 128 # Dimension of the embedding vector.
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  vocabulary_embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size * vocabulary_size, embedding_size], -1.0, 1.0))
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_chars = train_data[:num_unrollings]
  train_inputs = zip(train_chars[:-1], train_chars[1:])
  train_labels = train_data[2:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    #print(i.get_shape())
    #print(i)
    bigram_index = tf.argmax(i[0], dimension=1) + vocabulary_size * tf.argmax(i[1], dimension=1)
    i_embed = tf.nn.embedding_lookup(vocabulary_embeddings, bigram_index)
    output, state = lstm_cell(i_embed, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    #print(logits.get_shape())
    #print(tf.concat(0, train_labels).get_shape())
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  #sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  sample_input = list()
  for _ in range(2):
    sample_input.append(tf.placeholder(tf.float32, shape=[1, vocabulary_size]))
  samp_in_index = tf.argmax(sample_input[0], dimension=1) + vocabulary_size * tf.argmax(sample_input[1], dimension=1)
  sample_input_embedding = tf.nn.embedding_lookup(vocabulary_embeddings, samp_in_index)
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input_embedding, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
import collections
num_steps = 7001
summary_frequency = 100

valid_batches = BatchGenerator(valid_text, 1, 2)

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[2:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          #feed = sample(random_distribution())
          feed = collections.deque(maxlen=2)
          for _ in range(2):  
            feed.append(random_distribution())
          #sentence = characters(feed)[0]
          sentence = characters(feed[0])[0] + characters(feed[1])[0]
          #print(sentence)
          #print(feed)
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({
                    sample_input[0]: feed[0],
                    sample_input[1]: feed[1]
                })
            #feed = sample(prediction)
            feed.append(sample(prediction))
            #sentence += characters(feed)[0]
            sentence += characters(feed[1])[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({
                    sample_input[0]: b[0],
                    sample_input[1]: b[1]
            })
        valid_logprob = valid_logprob + logprob(predictions, b[2])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.295616 learning rate: 10.000000
# Minibatch perplexity: 26.99
# ================================================================================
# yp drrlytg chvv  keyayipjijow pzje nr lehoawnrda rqxsntrb uommbsxvyaqeyque he eya
# z gwy  aevhsyot wen rrr  oahehpx albzoez adon nmxwbb zjofqb xg afr okt nf xsaxef
# gi vja prinakkntcrrera takrx t gnch b eryan rajdloeqttntletuce  su qjzgoszzt sd i
# sve jeasroiitm  vqqtazzlwnp exxzvakiyaom xnmagyaloy sq  n u npadpd sl  a fne g az
# oibe hpf peefvapdfisacopaae ifefpybevlb  eebm rhr zrgul  oaorqfii uwastoeqnhbu ce
# ================================================================================
# Validation set perplexity: 19.62
# Average loss at step 100: 2.298215 learning rate: 10.000000
# Minibatch perplexity: 7.45
# Validation set perplexity: 9.71
# Average loss at step 200: 1.979455 learning rate: 10.000000
# Minibatch perplexity: 6.65
# Validation set perplexity: 8.57
# Average loss at step 300: 1.846124 learning rate: 10.000000
# Minibatch perplexity: 6.23
# Validation set perplexity: 8.24
# Average loss at step 400: 1.826589 learning rate: 10.000000
# Minibatch perplexity: 6.07
# Validation set perplexity: 8.19
# Average loss at step 500: 1.784840 learning rate: 10.000000
# Minibatch perplexity: 5.36
# Validation set perplexity: 7.81
# Average loss at step 600: 1.762482 learning rate: 10.000000
# Minibatch perplexity: 5.98
# Validation set perplexity: 7.62
# Average loss at step 700: 1.735209 learning rate: 10.000000
# Minibatch perplexity: 5.53
# Validation set perplexity: 7.44
# Average loss at step 800: 1.712627 learning rate: 10.000000
# Minibatch perplexity: 5.18
# Validation set perplexity: 7.36
# Average loss at step 900: 1.720362 learning rate: 10.000000
# Minibatch perplexity: 5.43
# Validation set perplexity: 7.46
# Average loss at step 1000: 1.699695 learning rate: 10.000000
# Minibatch perplexity: 5.17
# ================================================================================
# lz use lef  elates is the avero accuse penticultle comons define four zero one ni
# jd the tofeat for millead sapited six howeverii rhalli reconded they were clong w
# wd shars inveap six have the is ominesisicing crometreason is his with anives kil
# tjin the abouth is ekcess anicities every arimatic universeet or seven day soetan
# joreaded six nine in pead to glycort man assentation breating from to stild a con
# ================================================================================
# Validation set perplexity: 7.52
# Average loss at step 1100: 1.696999 learning rate: 10.000000
# Minibatch perplexity: 5.63
# Validation set perplexity: 7.58
# Average loss at step 1200: 1.677585 learning rate: 10.000000
# Minibatch perplexity: 5.31
# Validation set perplexity: 7.54
# Average loss at step 1300: 1.661585 learning rate: 10.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 7.38
# Average loss at step 1400: 1.640598 learning rate: 10.000000
# Minibatch perplexity: 5.36
# Validation set perplexity: 7.46
# Average loss at step 1500: 1.669842 learning rate: 10.000000
# Minibatch perplexity: 5.27
# Validation set perplexity: 7.27
# Average loss at step 1600: 1.674840 learning rate: 10.000000
# Minibatch perplexity: 4.94
# Validation set perplexity: 7.29
# Average loss at step 1700: 1.671970 learning rate: 10.000000
# Minibatch perplexity: 6.59
# Validation set perplexity: 7.41
# Average loss at step 1800: 1.654891 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 7.07
# Average loss at step 1900: 1.660464 learning rate: 10.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 6.69
# Average loss at step 2000: 1.667054 learning rate: 10.000000
# Minibatch perplexity: 4.77
# ================================================================================
# stiala be ceroted his angeles of ganns was a seigins in the clood wmr de  ealmake
# zqtd states the to kach cerentakes with led for expline one nce winessorn eanched
# gca and was mina toboylia only whisses that liber died which bash a referrecting
# kuth both lemibrity typiland us in many is angelism as if mainia within his wents
# uhum the piritener compnte timersion our and reapility computer unty one nine six
# ================================================================================
# Validation set perplexity: 7.00
# Average loss at step 2100: 1.647662 learning rate: 10.000000
# Minibatch perplexity: 5.46
# Validation set perplexity: 6.84
# Average loss at step 2200: 1.651076 learning rate: 10.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 7.35
# Average loss at step 2300: 1.658569 learning rate: 10.000000
# Minibatch perplexity: 5.53
# Validation set perplexity: 7.33
# Average loss at step 2400: 1.650117 learning rate: 10.000000
# Minibatch perplexity: 5.25
# Validation set perplexity: 6.79
# Average loss at step 2500: 1.634550 learning rate: 10.000000
# Minibatch perplexity: 5.07
# Validation set perplexity: 7.53
# Average loss at step 2600: 1.613086 learning rate: 10.000000
# Minibatch perplexity: 5.04
# Validation set perplexity: 7.85
# Average loss at step 2700: 1.639651 learning rate: 10.000000
# Minibatch perplexity: 6.23
# Validation set perplexity: 7.46
# Average loss at step 2800: 1.636744 learning rate: 10.000000
# Minibatch perplexity: 4.68
# Validation set perplexity: 7.51
# Average loss at step 2900: 1.615833 learning rate: 10.000000
# Minibatch perplexity: 4.50
# Validation set perplexity: 7.31
# Average loss at step 3000: 1.623581 learning rate: 10.000000
# Minibatch perplexity: 4.80
# ================================================================================
# ehi of lums that of greater bih known foree in a would frienal dated in the socie
# il ours communistic communcguis under by palease been isover essax they of likele
# bkoadoccational strilm unch as that two zero of recordivil real cboften politicia
# aggager of film not choing early  e  award presentastions at and offee of suffive
#  rone eight to government electrice sadvlryone arch of outptue socially that char
# ================================================================================
# Validation set perplexity: 7.52
# Average loss at step 3100: 1.627085 learning rate: 10.000000
# Minibatch perplexity: 5.05
# Validation set perplexity: 7.07
# Average loss at step 3200: 1.613980 learning rate: 10.000000
# Minibatch perplexity: 4.80
# Validation set perplexity: 7.46
# Average loss at step 3300: 1.617040 learning rate: 10.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 6.99
# Average loss at step 3400: 1.623504 learning rate: 10.000000
# Minibatch perplexity: 5.14
# Validation set perplexity: 7.32
# Average loss at step 3500: 1.601965 learning rate: 10.000000
# Minibatch perplexity: 5.05
# Validation set perplexity: 7.70
# Average loss at step 3600: 1.592113 learning rate: 10.000000
# Minibatch perplexity: 4.11
# Validation set perplexity: 7.61
# Average loss at step 3700: 1.598677 learning rate: 10.000000
# Minibatch perplexity: 4.76
# Validation set perplexity: 7.35
# Average loss at step 3800: 1.611138 learning rate: 10.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 7.59
# Average loss at step 3900: 1.637938 learning rate: 10.000000
# Minibatch perplexity: 5.73
# Validation set perplexity: 7.64
# Average loss at step 4000: 1.588659 learning rate: 10.000000
# Minibatch perplexity: 4.81
# ================================================================================
# qie or islopoles to the isel buildly december one nine isbn ell timerican the tem
# wlef into known bulado industry compnnels one nine eight six black george like uk
# nmor myri what fgamerican counts the primen of sport yo everistria this gplumal u
# pbeginsput a external elev then garles sfisifieter drome two zero in seater was w
# menzed to are work metamentants origing to that book thus c island life a legism
# ================================================================================
# Validation set perplexity: 7.71
# Average loss at step 4100: 1.565706 learning rate: 10.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 7.16
# Average loss at step 4200: 1.604230 learning rate: 10.000000
# Minibatch perplexity: 5.14
# Validation set perplexity: 8.14
# Average loss at step 4300: 1.573968 learning rate: 10.000000
# Minibatch perplexity: 4.90
# Validation set perplexity: 7.45
# Average loss at step 4400: 1.587517 learning rate: 10.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 7.53
# Average loss at step 4500: 1.608612 learning rate: 10.000000
# Minibatch perplexity: 4.99
# Validation set perplexity: 7.45
# Average loss at step 4600: 1.591346 learning rate: 10.000000
# Minibatch perplexity: 4.81
# Validation set perplexity: 7.51
# Average loss at step 4700: 1.618899 learning rate: 10.000000
# Minibatch perplexity: 5.65
# Validation set perplexity: 7.39
# Average loss at step 4800: 1.620582 learning rate: 10.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 7.67
# Average loss at step 4900: 1.606068 learning rate: 10.000000
# Minibatch perplexity: 4.93
# Validation set perplexity: 7.62
# Average loss at step 5000: 1.590699 learning rate: 1.000000
# Minibatch perplexity: 4.43
# ================================================================================
# wlened the ro the all asiam a musefaporal forregious accerry are ather indioatic
# lbothed bill out unleing at this efforter front of titley became of sonomily for
# als by american minaribegoground to energy will two eight a scheive had them a br
# mr two six acgod to two four four nine nine to perfortiblimition of the readicate
# rnism efulgenerally one one nine seven one seven three eight eight ning b bernant
# ================================================================================
# Validation set perplexity: 7.63
# Average loss at step 5100: 1.588759 learning rate: 1.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 7.29
# Average loss at step 5200: 1.563737 learning rate: 1.000000
# Minibatch perplexity: 4.48
# Validation set perplexity: 7.15
# Average loss at step 5300: 1.566977 learning rate: 1.000000
# Minibatch perplexity: 4.68
# Validation set perplexity: 7.14
# Average loss at step 5400: 1.548351 learning rate: 1.000000
# Minibatch perplexity: 4.70
# Validation set perplexity: 7.12
# Average loss at step 5500: 1.576331 learning rate: 1.000000
# Minibatch perplexity: 4.59
# Validation set perplexity: 7.04
# Average loss at step 5600: 1.573690 learning rate: 1.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 7.17
# Average loss at step 5700: 1.553582 learning rate: 1.000000
# Minibatch perplexity: 4.47
# Validation set perplexity: 7.14
# Average loss at step 5800: 1.544650 learning rate: 1.000000
# Minibatch perplexity: 4.53
# Validation set perplexity: 7.01
# Average loss at step 5900: 1.587386 learning rate: 1.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 7.14
# Average loss at step 6000: 1.584282 learning rate: 1.000000
# Minibatch perplexity: 5.97
# ================================================================================
# mus of variale faile directionland and informain impriters the a comic implanks f
# lne for slafgards known physicise mikland b five four hrozsrsell execularding and
# jd starzero in schoug soecw other drons then a between sourc backt leader and for
# hgp more at the fewtics with it impletse planoid lorded the motory modern amber o
# ks africat the listdr galso ealxcharaduled by their the caption drivear badwos th
# ================================================================================
# Validation set perplexity: 7.13
# Average loss at step 6100: 1.564332 learning rate: 1.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 7.17
# Average loss at step 6200: 1.587105 learning rate: 1.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 7.19
# Average loss at step 6300: 1.575030 learning rate: 1.000000
# Minibatch perplexity: 4.91
# Validation set perplexity: 7.04
# Average loss at step 6400: 1.574544 learning rate: 1.000000
# Minibatch perplexity: 4.30
# Validation set perplexity: 7.01
# Average loss at step 6500: 1.569747 learning rate: 1.000000
# Minibatch perplexity: 4.79
# Validation set perplexity: 7.06
# Average loss at step 6600: 1.586243 learning rate: 1.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 7.02
# Average loss at step 6700: 1.601594 learning rate: 1.000000
# Minibatch perplexity: 4.71
# Validation set perplexity: 6.97
# Average loss at step 6800: 1.582020 learning rate: 1.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 7.00
# Average loss at step 6900: 1.572104 learning rate: 1.000000
# Minibatch perplexity: 4.49
# Validation set perplexity: 7.02
# Average loss at step 7000: 1.560366 learning rate: 1.000000
# Minibatch perplexity: 5.28
# ================================================================================
# rve recivirail and fins ships within next first publand s cermar additations the
# fnmor sumply or time olyvership gardenbn of the pryphraishing to pows with has th
# great one five six the niest tow organizaessive soxell and start in ankurnist of
# yj we fliviring wrotic quike ca laoft field of the trade and cenly abgeles and th
#  prolutional novelhumnized the trans interation which the five eight pupigatures
# ================================================================================
# Validation set perplexity: 6.99

# %% [markdown]
# It works, but the validation perplexity is a bit worst.
#
# Let's try the dropout, in the inputs/ouputs only, not between to cells.

# %%
embedding_size = 128 # Dimension of the embedding vector.
num_nodes = 64
keep_prob_train = 1.0

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  vocabulary_embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size * vocabulary_size, embedding_size], -1.0, 1.0))
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state
  
  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_chars = train_data[:num_unrollings]
  train_inputs = zip(train_chars[:-1], train_chars[1:])
  train_labels = train_data[2:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    bigram_index = tf.argmax(i[0], dimension=1) + vocabulary_size * tf.argmax(i[1], dimension=1)
    i_embed = tf.nn.embedding_lookup(vocabulary_embeddings, bigram_index)
    drop_i = tf.nn.dropout(i_embed, keep_prob_train)
    output, state = lstm_cell(drop_i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    drop_logits = tf.nn.dropout(logits, keep_prob_train)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 15000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  #sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  keep_prob_sample = tf.placeholder(tf.float32)
  sample_input = list()
  for _ in range(2):
    sample_input.append(tf.placeholder(tf.float32, shape=[1, vocabulary_size]))
  samp_in_index = tf.argmax(sample_input[0], dimension=1) + vocabulary_size * tf.argmax(sample_input[1], dimension=1)
  sample_input_embedding = tf.nn.embedding_lookup(vocabulary_embeddings, samp_in_index)
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input_embedding, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
import collections
num_steps = 21001
summary_frequency = 100

valid_batches = BatchGenerator(valid_text, 1, 2)

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[2:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          #feed = sample(random_distribution())
          feed = collections.deque(maxlen=2)
          for _ in range(2):  
            feed.append(random_distribution())
          #sentence = characters(feed)[0]
          sentence = characters(feed[0])[0] + characters(feed[1])[0]
          #print(sentence)
          #print(feed)
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({
                    sample_input[0]: feed[0],
                    sample_input[1]: feed[1],
                })
            #feed = sample(prediction)
            feed.append(sample(prediction))
            #sentence += characters(feed)[0]
            sentence += characters(feed[1])[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({
                sample_input[0]: b[0],
                sample_input[1]: b[1],
                keep_prob_sample: 1.0
            })
        valid_logprob = valid_logprob + logprob(predictions, b[2])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.318233 learning rate: 10.000000
# Minibatch perplexity: 27.61
# ================================================================================
# axndpft u kkijz m raeqdt u  emsio biii  bay  y sqwhumiq jbei yb  tevln   rjnjo di
# ihha dzgefsxk fx pbup itbrrhe  wtlt paeudxmxhm  ogo  renwbkc wk wg no fpv poyohfx
# gxa fhrshrv bexaux er e aidalri qw egthoog nue avekd oi cru b jverh  tk pmz zlcvh
# scwy oocntgpe waqnj ltjmo twric h  puxfa g  set  anzfojqhctw  gtytahwvv pe yuazye
# tgaxk honkxibvbdoyothscrokty en qkoat at h  i jo ofamh frtetztm aj w  t ezk b ofh
# ================================================================================
# Validation set perplexity: 20.35
# Average loss at step 100: 2.300376 learning rate: 10.000000
# Minibatch perplexity: 7.45
# Validation set perplexity: 9.39
# Average loss at step 200: 1.981535 learning rate: 10.000000
# Minibatch perplexity: 6.88
# Validation set perplexity: 8.41
# Average loss at step 300: 1.881706 learning rate: 10.000000
# Minibatch perplexity: 6.76
# Validation set perplexity: 8.09
# Average loss at step 400: 1.820855 learning rate: 10.000000
# Minibatch perplexity: 6.40
# Validation set perplexity: 8.10
# Average loss at step 500: 1.795252 learning rate: 10.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 8.11
# Average loss at step 600: 1.742961 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 7.83
# Average loss at step 700: 1.741904 learning rate: 10.000000
# Minibatch perplexity: 5.61
# Validation set perplexity: 7.81
# Average loss at step 800: 1.723990 learning rate: 10.000000
# Minibatch perplexity: 6.20
# Validation set perplexity: 7.66
# Average loss at step 900: 1.705402 learning rate: 10.000000
# Minibatch perplexity: 6.07
# Validation set perplexity: 7.94
# Average loss at step 1000: 1.703635 learning rate: 10.000000
# Minibatch perplexity: 5.45
# ================================================================================
# fxuus story which s to part do dreat you was build s onert ances be three zero ex
# fqcreation assii on it if expan curruse naments lappient in banced to tunds of mo
# pbbruns of bilt advice that not on chife in one perlined in everyning boon   emni
# ugh to to stowers of frespations to the arbanothen simplete as li frenz such conf
# uzbsage recorder weakings to beled an and in farite records or modur only the dab
# ================================================================================
# Validation set perplexity: 7.71
# Average loss at step 1100: 1.674853 learning rate: 10.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 7.79
# Average loss at step 1200: 1.677775 learning rate: 10.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 7.50
# Average loss at step 1300: 1.700387 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 7.72
# Average loss at step 1400: 1.692142 learning rate: 10.000000
# Minibatch perplexity: 5.42
# Validation set perplexity: 7.52
# Average loss at step 1500: 1.664646 learning rate: 10.000000
# Minibatch perplexity: 5.81
# Validation set perplexity: 7.23
# Average loss at step 1600: 1.691266 learning rate: 10.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 7.56
# Average loss at step 1700: 1.680819 learning rate: 10.000000
# Minibatch perplexity: 5.31
# Validation set perplexity: 7.79
# Average loss at step 1800: 1.658236 learning rate: 10.000000
# Minibatch perplexity: 5.77
# Validation set perplexity: 7.57
# Average loss at step 1900: 1.633818 learning rate: 10.000000
# Minibatch perplexity: 4.81
# Validation set perplexity: 7.84
# Average loss at step 2000: 1.638415 learning rate: 10.000000
# Minibatch perplexity: 5.17
# ================================================================================
# ul number other not ny discuss ched in nof their al less he different enbude anol
# kxpost empicular zero zero zero zero zero zero zero two th cisco vock in person i
# krhin one decide on two resident gived hert unch that ctallor compride and hampo
# cy member over in the educations rulates the and large shot service project the s
# wing has memping the jason four february atafinizar of col homember known and the
# ================================================================================
# Validation set perplexity: 7.59
# Average loss at step 2100: 1.665611 learning rate: 10.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 7.40
# Average loss at step 2200: 1.652986 learning rate: 10.000000
# Minibatch perplexity: 5.04
# Validation set perplexity: 7.66
# Average loss at step 2300: 1.633312 learning rate: 10.000000
# Minibatch perplexity: 5.42
# Validation set perplexity: 7.45
# Average loss at step 2400: 1.626916 learning rate: 10.000000
# Minibatch perplexity: 4.63
# Validation set perplexity: 7.91
# Average loss at step 2500: 1.613027 learning rate: 10.000000
# Minibatch perplexity: 6.14
# Validation set perplexity: 7.75
# Average loss at step 2600: 1.631954 learning rate: 10.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 7.86
# Average loss at step 2700: 1.605110 learning rate: 10.000000
# Minibatch perplexity: 4.62
# Validation set perplexity: 7.49
# Average loss at step 2800: 1.614674 learning rate: 10.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 7.39
# Average loss at step 2900: 1.637991 learning rate: 10.000000
# Minibatch perplexity: 5.10
# Validation set perplexity: 7.91
# Average loss at step 3000: 1.629412 learning rate: 10.000000
# Minibatch perplexity: 5.50
# ================================================================================
# jnce three one and of the some intellizause in over name hollecture british milk
# rs inments was en which ply sequence francery official has jeople forms re impres
# bled webdinal of musicial consimplan a formainre zero nine eight one zero zero da
# yoether cours taken final mards use buigni cotos welcover this hwalled fru devele
# wjdom mahmin other thani is faugke in had literal york the north posies their lea
# ================================================================================
# Validation set perplexity: 7.45
# Average loss at step 3100: 1.611876 learning rate: 10.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 7.42
# Average loss at step 3200: 1.613643 learning rate: 10.000000
# Minibatch perplexity: 5.93
# Validation set perplexity: 7.72
# Average loss at step 3300: 1.595553 learning rate: 10.000000
# Minibatch perplexity: 4.69
# Validation set perplexity: 7.70
# Average loss at step 3400: 1.580889 learning rate: 10.000000
# Minibatch perplexity: 4.29
# Validation set perplexity: 8.09
# Average loss at step 3500: 1.596029 learning rate: 10.000000
# Minibatch perplexity: 4.65
# Validation set perplexity: 7.76
# Average loss at step 3600: 1.617184 learning rate: 10.000000
# Minibatch perplexity: 5.14
# Validation set perplexity: 7.97
# Average loss at step 3700: 1.626510 learning rate: 10.000000
# Minibatch perplexity: 5.10
# Validation set perplexity: 7.30
# Average loss at step 3800: 1.598437 learning rate: 10.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 7.62
# Average loss at step 3900: 1.614367 learning rate: 10.000000
# Minibatch perplexity: 4.93
# Validation set perplexity: 7.86
# Average loss at step 4000: 1.603298 learning rate: 10.000000
# Minibatch perplexity: 6.62
# ================================================================================
# cephlyirraye is give the tankrupted to the freen so contempts of cmc instrumentio
# px heting and the auldel state most chip a maching not mainnes will pc sysles oup
# afterhaps ran one in exsepte jaudians of mahboth bote to usdom this lebegin the b
# in one nine five it people speranto blochampion one nine nine eight two zero zero
# vwms the familian of lented the games greatmentaling milliant cent speakorging do
# ================================================================================
# Validation set perplexity: 7.46
# Average loss at step 4100: 1.577691 learning rate: 10.000000
# Minibatch perplexity: 4.32
# Validation set perplexity: 7.07
# Average loss at step 4200: 1.603897 learning rate: 10.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 7.60
# Average loss at step 4300: 1.605523 learning rate: 10.000000
# Minibatch perplexity: 5.27
# Validation set perplexity: 7.97
# Average loss at step 4400: 1.585078 learning rate: 10.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 7.64
# Average loss at step 4500: 1.600731 learning rate: 10.000000
# Minibatch perplexity: 5.03
# Validation set perplexity: 7.54
# Average loss at step 4600: 1.601758 learning rate: 10.000000
# Minibatch perplexity: 4.84
# Validation set perplexity: 7.63
# Average loss at step 4700: 1.589291 learning rate: 10.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 7.71
# Average loss at step 4800: 1.606257 learning rate: 10.000000
# Minibatch perplexity: 5.68
# Validation set perplexity: 7.18
# Average loss at step 4900: 1.595243 learning rate: 10.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 7.14
# Average loss at step 5000: 1.609005 learning rate: 10.000000
# Minibatch perplexity: 5.21
# ================================================================================
#   aro algorithm iz reger gelative consring to have a commor formed to ca heracy t
# vpi hen system for provict and cariii frain effect generate of fiell all can plac
# ljabiling prounced to became the efficialistics one eight seven orubsire declare
# in another not because right one nine his were a clearly dlen staten both lyritic
# oquestan intervys veros chemandii back the mary struggely conteme pngs intions in
# ================================================================================
# Validation set perplexity: 7.48
# Average loss at step 5100: 1.580667 learning rate: 10.000000
# Minibatch perplexity: 4.57
# Validation set perplexity: 7.62
# Average loss at step 5200: 1.575430 learning rate: 10.000000
# Minibatch perplexity: 4.54
# Validation set perplexity: 7.14
# Average loss at step 5300: 1.585925 learning rate: 10.000000
# Minibatch perplexity: 5.10
# Validation set perplexity: 6.96
# Average loss at step 5400: 1.607855 learning rate: 10.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 7.16
# Average loss at step 5500: 1.588680 learning rate: 10.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 6.82
# Average loss at step 5600: 1.574256 learning rate: 10.000000
# Minibatch perplexity: 4.82
# Validation set perplexity: 7.27
# Average loss at step 5700: 1.581678 learning rate: 10.000000
# Minibatch perplexity: 4.49
# Validation set perplexity: 7.29
# Average loss at step 5800: 1.611185 learning rate: 10.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 7.45
# Average loss at step 5900: 1.605943 learning rate: 10.000000
# Minibatch perplexity: 4.51
# Validation set perplexity: 7.13
# Average loss at step 6000: 1.590164 learning rate: 10.000000
# Minibatch perplexity: 4.93
# ================================================================================
# ln la noted too is a he was again formoneastory in flew york to one by the volief
# zsddnal molian plar both several is one zero publed a lats of the u quezone explo
# zweared to illine siexplo fight theintraut succes even includeman titli from the
# k to laterouded to rain closed to two three cal elected imbinisternet in two zero
# rder multipse to example khat of cression hanmid daust pas westor threo japan for
# ================================================================================
# Validation set perplexity: 7.49
# Average loss at step 6100: 1.612037 learning rate: 10.000000
# Minibatch perplexity: 5.49
# Validation set perplexity: 7.36
# Average loss at step 6200: 1.613247 learning rate: 10.000000
# Minibatch perplexity: 4.38
# Validation set perplexity: 7.29
# Average loss at step 6300: 1.639463 learning rate: 10.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 7.40
# Average loss at step 6400: 1.605295 learning rate: 10.000000
# Minibatch perplexity: 5.71
# Validation set perplexity: 7.48
# Average loss at step 6500: 1.606173 learning rate: 10.000000
# Minibatch perplexity: 4.94
# Validation set perplexity: 7.38
# Average loss at step 6600: 1.588547 learning rate: 10.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 7.22
# Average loss at step 6700: 1.562366 learning rate: 10.000000
# Minibatch perplexity: 4.88
# Validation set perplexity: 7.20
# Average loss at step 6800: 1.600738 learning rate: 10.000000
# Minibatch perplexity: 4.62
# Validation set perplexity: 7.03
# Average loss at step 6900: 1.602074 learning rate: 10.000000
# Minibatch perplexity: 5.39
# Validation set perplexity: 6.87
# Average loss at step 7000: 1.586539 learning rate: 10.000000
# Minibatch perplexity: 4.45
# ================================================================================
# bku and linguisters of siker coling after one nine five four two za h are sees of
# xving one eight proper in oil maggressed insuraist would and protebreka is becond
# kggloss defeated to sing the explah d to d youtunge the greek againing therely bc
# dj and a cs to city in love cpsatugh zero zue five the knowayer of what protearre
# on both jaragged unteriousing and aney withil uch using stike treeklysitional sur
# ================================================================================
# Validation set perplexity: 6.65
# Average loss at step 7100: 1.603331 learning rate: 10.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 6.75
# Average loss at step 7200: 1.596783 learning rate: 10.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 7.11
# Average loss at step 7300: 1.592299 learning rate: 10.000000
# Minibatch perplexity: 5.49
# Validation set perplexity: 7.25
# Average loss at step 7400: 1.575894 learning rate: 10.000000
# Minibatch perplexity: 4.65
# Validation set perplexity: 6.85
# Average loss at step 7500: 1.586952 learning rate: 10.000000
# Minibatch perplexity: 4.67
# Validation set perplexity: 7.22
# Average loss at step 7600: 1.615823 learning rate: 10.000000
# Minibatch perplexity: 4.23
# Validation set perplexity: 7.13
# Average loss at step 7700: 1.603395 learning rate: 10.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 6.79
# Average loss at step 7800: 1.605332 learning rate: 10.000000
# Minibatch perplexity: 4.89
# Validation set perplexity: 7.11
# Average loss at step 7900: 1.569873 learning rate: 10.000000
# Minibatch perplexity: 5.27
# Validation set perplexity: 7.00
# Average loss at step 8000: 1.597829 learning rate: 10.000000
# Minibatch perplexity: 5.01
# ================================================================================
# rpecth the gulphy one four al swaits fuch groups entermine of this god samdry z o
# lf could s used to the countury after in alway is retween the gling in play is no
# xass idencs hypotled homo which the first is journing inflations of the newfw  re
# gxrnock killy the south contened polin after menic ricened federal is common idea
# lcoundrayer very of the deorzahased played with chantures exportralys to the and
# ================================================================================
# Validation set perplexity: 7.24
# Average loss at step 8100: 1.603912 learning rate: 10.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 7.17
# Average loss at step 8200: 1.595368 learning rate: 10.000000
# Minibatch perplexity: 5.01
# Validation set perplexity: 7.18
# Average loss at step 8300: 1.615709 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 7.13
# Average loss at step 8400: 1.610932 learning rate: 10.000000
# Minibatch perplexity: 4.90
# Validation set perplexity: 7.14
# Average loss at step 8500: 1.582590 learning rate: 10.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 7.18
# Average loss at step 8600: 1.615855 learning rate: 10.000000
# Minibatch perplexity: 3.87
# Validation set perplexity: 7.12
# Average loss at step 8700: 1.593863 learning rate: 10.000000
# Minibatch perplexity: 4.90
# Validation set perplexity: 7.17
# Average loss at step 8800: 1.601905 learning rate: 10.000000
# Minibatch perplexity: 4.71
# Validation set perplexity: 7.13
# Average loss at step 8900: 1.617800 learning rate: 10.000000
# Minibatch perplexity: 4.71
# Validation set perplexity: 7.37
# Average loss at step 9000: 1.618448 learning rate: 10.000000
# Minibatch perplexity: 4.85
# ================================================================================
# hus historypted average and ety airpose used wide one eight zero six stille diste
# rs and in that some as fought survice asrocks the characteriest specific the lace
# jflen and followever theory arshibit baria which are in some coenomped astrabecon
# ys all asia vourhop thereforeen one one five one nine seven ashese somose ologica
# z m from steoplaces lears hera by flated phaehra del to image h bospany members a
# ================================================================================
# Validation set perplexity: 7.29
# Average loss at step 9100: 1.607244 learning rate: 10.000000
# Minibatch perplexity: 5.19
# Validation set perplexity: 7.19
# Average loss at step 9200: 1.600960 learning rate: 10.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 6.84
# Average loss at step 9300: 1.606514 learning rate: 10.000000
# Minibatch perplexity: 4.39
# Validation set perplexity: 7.24
# Average loss at step 9400: 1.609098 learning rate: 10.000000
# Minibatch perplexity: 5.38
# Validation set perplexity: 7.28
# Average loss at step 9500: 1.606239 learning rate: 10.000000
# Minibatch perplexity: 4.83
# Validation set perplexity: 7.25
# Average loss at step 9600: 1.603416 learning rate: 10.000000
# Minibatch perplexity: 4.78
# Validation set perplexity: 6.88
# Average loss at step 9700: 1.578568 learning rate: 10.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 7.21
# Average loss at step 9800: 1.600332 learning rate: 10.000000
# Minibatch perplexity: 4.56
# Validation set perplexity: 7.40
# Average loss at step 9900: 1.610834 learning rate: 10.000000
# Minibatch perplexity: 6.00
# Validation set perplexity: 7.45
# Average loss at step 10000: 1.587599 learning rate: 10.000000
# Minibatch perplexity: 4.65
# ================================================================================
# ying infjurality and trollu martina most many s and one s his offerund the towmat
# xper to e from three threlied as as of igart of anya often they lithubbany oncent
# fulution he line victorital was american needs the xam by a revollife munitubeitz
# ft known dibaa used also john charghed one nine one four seven and exwualissiate
# gdles set soldingway about a primes emerbuse percility of agent tract the beganiz
# ================================================================================
# Validation set perplexity: 6.83
# Average loss at step 10100: 1.600719 learning rate: 10.000000
# Minibatch perplexity: 4.48
# Validation set perplexity: 7.47
# Average loss at step 10200: 1.613219 learning rate: 10.000000
# Minibatch perplexity: 5.10
# Validation set perplexity: 7.35
# Average loss at step 10300: 1.597366 learning rate: 10.000000
# Minibatch perplexity: 4.64
# Validation set perplexity: 7.35
# Average loss at step 10400: 1.575514 learning rate: 10.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 7.12
# Average loss at step 10500: 1.578663 learning rate: 10.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 7.20
# Average loss at step 10600: 1.604494 learning rate: 10.000000
# Minibatch perplexity: 5.76
# Validation set perplexity: 7.42
# Average loss at step 10700: 1.593033 learning rate: 10.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 7.12
# Average loss at step 10800: 1.566429 learning rate: 10.000000
# Minibatch perplexity: 5.47
# Validation set perplexity: 7.53
# Average loss at step 10900: 1.569692 learning rate: 10.000000
# Minibatch perplexity: 4.38
# Validation set perplexity: 7.11
# Average loss at step 11000: 1.564907 learning rate: 10.000000
# Minibatch perplexity: 4.99
# ================================================================================
# ver the strant synthesed in an or this upies of more broadcally nati plicts the p
# jflags ult he awai inf the sholic s right or astis and the number one nine nine t
# cke nine nine eight two thas the camember sefuniver zero four course had a then t
# dfour that of these the pressingsle bicazed jureourse about uvnest maticks and bu
# ualy have anti claim a partly rs and due hons hand bast september marriaged plain
# ================================================================================
# Validation set perplexity: 7.13
# Average loss at step 11100: 1.559474 learning rate: 10.000000
# Minibatch perplexity: 4.57
# Validation set perplexity: 7.14
# Average loss at step 11200: 1.559971 learning rate: 10.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 7.31
# Average loss at step 11300: 1.577388 learning rate: 10.000000
# Minibatch perplexity: 4.69
# Validation set perplexity: 7.08
# Average loss at step 11400: 1.527645 learning rate: 10.000000
# Minibatch perplexity: 4.32
# Validation set perplexity: 7.36
# Average loss at step 11500: 1.546103 learning rate: 10.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 7.20
# Average loss at step 11600: 1.566596 learning rate: 10.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 7.12
# Average loss at step 11700: 1.557056 learning rate: 10.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 7.30
# Average loss at step 11800: 1.533829 learning rate: 10.000000
# Minibatch perplexity: 4.83
# Validation set perplexity: 6.91
# Average loss at step 11900: 1.537516 learning rate: 10.000000
# Minibatch perplexity: 4.33
# Validation set perplexity: 7.03
# Average loss at step 12000: 1.572812 learning rate: 10.000000
# Minibatch perplexity: 4.86
# ================================================================================
# gnie v can is spring intefluents dequent as the circis the boths pop c the s demo
# skood in arracist sexicted a buther actively s versities a national bob the seal
# jvant wep two zero zero player faronees after dan ourned after b one six six six
#  his guing papesmin the tronco was lipai angolled bangle those eifes anstommil ot
#  gameleans half as the rk the accities on exile small or his grapied however for
# ================================================================================
# Validation set perplexity: 6.99
# Average loss at step 12100: 1.552006 learning rate: 10.000000
# Minibatch perplexity: 4.50
# Validation set perplexity: 7.00
# Average loss at step 12200: 1.593685 learning rate: 10.000000
# Minibatch perplexity: 4.96
# Validation set perplexity: 6.99
# Average loss at step 12300: 1.563639 learning rate: 10.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 6.92
# Average loss at step 12400: 1.546993 learning rate: 10.000000
# Minibatch perplexity: 4.45
# Validation set perplexity: 7.10
# Average loss at step 12500: 1.561110 learning rate: 10.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 6.59
# Average loss at step 12600: 1.571592 learning rate: 10.000000
# Minibatch perplexity: 4.69
# Validation set perplexity: 7.08
# Average loss at step 12700: 1.593175 learning rate: 10.000000
# Minibatch perplexity: 4.65
# Validation set perplexity: 6.89
# Average loss at step 12800: 1.562593 learning rate: 10.000000
# Minibatch perplexity: 4.76
# Validation set perplexity: 7.05
# Average loss at step 12900: 1.575785 learning rate: 10.000000
# Minibatch perplexity: 5.62
# Validation set perplexity: 7.32
# Average loss at step 13000: 1.595146 learning rate: 10.000000
# Minibatch perplexity: 4.97
# ================================================================================
# filed and nine one nine four in on toriet as in verdam pery and popular given of
# ygerance habition softwateng pared into the war their systemon moso bruggointal t
# fxactoida in atresion of one nine he collect about minilace years a dipmination w
# oad service wity is psleithain i informatunrus gee two nine eight puntations zoal
# w watting at part and othe in one seven two two restract a computerials that thin
# ================================================================================
# Validation set perplexity: 7.23
# Average loss at step 13100: 1.592201 learning rate: 10.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 7.07
# Average loss at step 13200: 1.576413 learning rate: 10.000000
# Minibatch perplexity: 4.65
# Validation set perplexity: 7.07
# Average loss at step 13300: 1.601515 learning rate: 10.000000
# Minibatch perplexity: 4.94
# Validation set perplexity: 7.25
# Average loss at step 13400: 1.579876 learning rate: 10.000000
# Minibatch perplexity: 4.46
# Validation set perplexity: 7.44
# Average loss at step 13500: 1.554404 learning rate: 10.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 6.95
# Average loss at step 13600: 1.547893 learning rate: 10.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 6.94
# Average loss at step 13700: 1.564939 learning rate: 10.000000
# Minibatch perplexity: 4.34
# Validation set perplexity: 6.92
# Average loss at step 13800: 1.560177 learning rate: 10.000000
# Minibatch perplexity: 4.02
# Validation set perplexity: 7.07
# Average loss at step 13900: 1.579256 learning rate: 10.000000
# Minibatch perplexity: 4.55
# Validation set perplexity: 7.02
# Average loss at step 14000: 1.588065 learning rate: 10.000000
# Minibatch perplexity: 4.93
# ================================================================================
# gation had broughts cographal east some ownised recetea on that term dollection c
# jokyor the wevi enterceptory for  universaking often tchall aniaterical this nowe
# zralis oadf capbber to a rights in the ske world britch a more pressivear appre c
# l wood or igaild buth wright are frant it is separe luthere newkclations at the e
# ujr the elected by with charliante cumm with of itself award ony divinginbed whim
# ================================================================================
# Validation set perplexity: 7.12
# Average loss at step 14100: 1.583414 learning rate: 10.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 7.21
# Average loss at step 14200: 1.590047 learning rate: 10.000000
# Minibatch perplexity: 5.28
# Validation set perplexity: 7.15
# Average loss at step 14300: 1.602797 learning rate: 10.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 7.11
# Average loss at step 14400: 1.594966 learning rate: 10.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 7.24
# Average loss at step 14500: 1.600312 learning rate: 10.000000
# Minibatch perplexity: 4.61
# Validation set perplexity: 7.56
# Average loss at step 14600: 1.599067 learning rate: 10.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 7.39
# Average loss at step 14700: 1.573204 learning rate: 10.000000
# Minibatch perplexity: 4.41
# Validation set perplexity: 7.41
# Average loss at step 14800: 1.584237 learning rate: 10.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 7.25
# Average loss at step 14900: 1.559842 learning rate: 10.000000
# Minibatch perplexity: 5.05
# Validation set perplexity: 7.63
# Average loss at step 15000: 1.570215 learning rate: 1.000000
# Minibatch perplexity: 4.97
# ================================================================================
# xx accombillican than it united royal manna inch the singer player ephicsugan per
# nk had cdlu king british of the uring be s the some study that buream  univers pr
# htmusing a sts insteeg isdal m ka malxrnshewere tiles provising rains with romanc
# fji aegyhr ecterms actually became of the printrink and the number disgandhi fact
# www and minylan eachinual ainly and drsond the brant by j many their rasing or in
# ================================================================================
# Validation set perplexity: 7.41
# Average loss at step 15100: 1.557820 learning rate: 1.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 7.14
# Average loss at step 15200: 1.547948 learning rate: 1.000000
# Minibatch perplexity: 4.91
# Validation set perplexity: 7.16
# Average loss at step 15300: 1.506547 learning rate: 1.000000
# Minibatch perplexity: 4.62
# Validation set perplexity: 7.08
# Average loss at step 15400: 1.534399 learning rate: 1.000000
# Minibatch perplexity: 5.25
# Validation set perplexity: 6.98
# Average loss at step 15500: 1.509638 learning rate: 1.000000
# Minibatch perplexity: 5.39
# Validation set perplexity: 6.92
# Average loss at step 15600: 1.500265 learning rate: 1.000000
# Minibatch perplexity: 4.30
# Validation set perplexity: 6.83
# Average loss at step 15700: 1.524085 learning rate: 1.000000
# Minibatch perplexity: 4.26
# Validation set perplexity: 6.80
# Average loss at step 15800: 1.530276 learning rate: 1.000000
# Minibatch perplexity: 4.40
# Validation set perplexity: 6.81
# Average loss at step 15900: 1.516483 learning rate: 1.000000
# Minibatch perplexity: 4.41
# Validation set perplexity: 6.83
# Average loss at step 16000: 1.500149 learning rate: 1.000000
# Minibatch perplexity: 4.50
# ================================================================================
# ping canony i anglas ibeing rappg assage enviwarin done army writtle of preserv s
# bqact involtons to parcha a palexate for a sixs in the lobesucw the differences o
# gzterning in centries however modern of mimpitatively king lyted also with p actu
# vb government social lomposed ident chips which planetic logic modern that the fo
# yvence one zero five is calculity nown u scoherminal come as one and su slund s i
# ================================================================================
# Validation set perplexity: 6.84
# Average loss at step 16100: 1.477546 learning rate: 1.000000
# Minibatch perplexity: 4.25
# Validation set perplexity: 6.79
# Average loss at step 16200: 1.526644 learning rate: 1.000000
# Minibatch perplexity: 4.79
# Validation set perplexity: 6.84
# Average loss at step 16300: 1.516223 learning rate: 1.000000
# Minibatch perplexity: 4.10
# Validation set perplexity: 6.85
# Average loss at step 16400: 1.540517 learning rate: 1.000000
# Minibatch perplexity: 5.33
# Validation set perplexity: 6.84
# Average loss at step 16500: 1.543026 learning rate: 1.000000
# Minibatch perplexity: 4.29
# Validation set perplexity: 6.79
# Average loss at step 16600: 1.512130 learning rate: 1.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 6.81
# Average loss at step 16700: 1.533238 learning rate: 1.000000
# Minibatch perplexity: 4.45
# Validation set perplexity: 6.86
# Average loss at step 16800: 1.524444 learning rate: 1.000000
# Minibatch perplexity: 4.70
# Validation set perplexity: 6.89
# Average loss at step 16900: 1.517303 learning rate: 1.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 6.88
# Average loss at step 17000: 1.550001 learning rate: 1.000000
# Minibatch perplexity: 5.12
# ================================================================================
# ed kurni s composittial walberto s domitto be driddlear only moon on the pup noug
# vroperia same may ben west y in oat in a senlic chevilized defeated fuse mand pri
# zarged increasis and as libignath indival office early the plong him b area is ny
# vm beale war laws dirally g hysion communist of as a long contnessitimines and te
# fur in the halve fabrids object upote links all unbert has dike reagaabs by seriv
# ================================================================================
# Validation set perplexity: 6.95
# Average loss at step 17100: 1.563136 learning rate: 1.000000
# Minibatch perplexity: 4.49
# Validation set perplexity: 6.95
# Average loss at step 17200: 1.576908 learning rate: 1.000000
# Minibatch perplexity: 4.49
# Validation set perplexity: 6.96
# Average loss at step 17300: 1.568692 learning rate: 1.000000
# Minibatch perplexity: 4.25
# Validation set perplexity: 6.94
# Average loss at step 17400: 1.588266 learning rate: 1.000000
# Minibatch perplexity: 4.68
# Validation set perplexity: 6.89
# Average loss at step 17500: 1.583767 learning rate: 1.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 6.87
# Average loss at step 17600: 1.560295 learning rate: 1.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 6.89
# Average loss at step 17700: 1.553252 learning rate: 1.000000
# Minibatch perplexity: 4.78
# Validation set perplexity: 6.97
# Average loss at step 17800: 1.515559 learning rate: 1.000000
# Minibatch perplexity: 4.50
# Validation set perplexity: 6.86
# Average loss at step 17900: 1.523938 learning rate: 1.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 6.89
# Average loss at step 18000: 1.537062 learning rate: 1.000000
# Minibatch perplexity: 4.54
# ================================================================================
#  his nine nine nine four seven and other city of the rule by boad s d in in the s
# vt two a rptified to ordams of that take of used with and majority of polity moun
# ategal of the shoples idence backby two three one zero four six zero four few s f
# kb four nine polonamile but expresel me cicity was deline pesh cortuypod his comm
# mote of amonor several dated molected the medie subjects and five is metal l some
# ================================================================================
# Validation set perplexity: 6.80
# Average loss at step 18100: 1.556431 learning rate: 1.000000
# Minibatch perplexity: 4.67
# Validation set perplexity: 6.83
# Average loss at step 18200: 1.557314 learning rate: 1.000000
# Minibatch perplexity: 4.79
# Validation set perplexity: 6.80
# Average loss at step 18300: 1.574987 learning rate: 1.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 6.76
# Average loss at step 18400: 1.563625 learning rate: 1.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 6.74
# Average loss at step 18500: 1.570903 learning rate: 1.000000
# Minibatch perplexity: 4.90
# Validation set perplexity: 6.74
# Average loss at step 18600: 1.561241 learning rate: 1.000000
# Minibatch perplexity: 4.76
# Validation set perplexity: 6.72
# Average loss at step 18700: 1.557796 learning rate: 1.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 6.78
# Average loss at step 18800: 1.597680 learning rate: 1.000000
# Minibatch perplexity: 4.76
# Validation set perplexity: 6.72
# Average loss at step 18900: 1.570735 learning rate: 1.000000
# Minibatch perplexity: 5.28
# Validation set perplexity: 6.79
# Average loss at step 19000: 1.559135 learning rate: 1.000000
# Minibatch perplexity: 5.03
# ================================================================================
# wkoniateswish lonjo of when vs history individed are zeirting atcril good bear mo
# very a portually have can be innern erie death of retain manage and purport found
# jvas g on janual antholics hisco sostors of or fundredics is margine was they rec
# fjms well even one zero zero zero zero zero zero zero directs communication telph
# familie a preduce same infhistories the at has jl images anti emergaying joaster
# ================================================================================
# Validation set perplexity: 6.76
# Average loss at step 19100: 1.556249 learning rate: 1.000000
# Minibatch perplexity: 4.68
# Validation set perplexity: 6.74
# Average loss at step 19200: 1.517479 learning rate: 1.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 6.73
# Average loss at step 19300: 1.554520 learning rate: 1.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 6.74
# Average loss at step 19400: 1.536559 learning rate: 1.000000
# Minibatch perplexity: 4.37
# Validation set perplexity: 6.76
# Average loss at step 19500: 1.554913 learning rate: 1.000000
# Minibatch perplexity: 4.18
# Validation set perplexity: 6.83
# Average loss at step 19600: 1.544321 learning rate: 1.000000
# Minibatch perplexity: 4.34
# Validation set perplexity: 6.89
# Average loss at step 19700: 1.536726 learning rate: 1.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 6.80
# Average loss at step 19800: 1.519492 learning rate: 1.000000
# Minibatch perplexity: 4.96
# Validation set perplexity: 6.82
# Average loss at step 19900: 1.533301 learning rate: 1.000000
# Minibatch perplexity: 4.64
# Validation set perplexity: 6.81
# Average loss at step 20000: 1.524188 learning rate: 1.000000
# Minibatch perplexity: 4.71
# ================================================================================
# writer who been counts web ball bring situated the developed by surfactor the whi
# fgh low of boff is each the two ics ediction of the roman period of a space stock
# yvers the received early other packip was adext back greatary thoothomics it won
# belling satvasiamed in multionshita else signification in never internative a gof
# gabelmd just the statra informabing univer related camboungrable of a marers acco
# ================================================================================
# Validation set perplexity: 6.84
# Average loss at step 20100: 1.554572 learning rate: 1.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 6.81
# Average loss at step 20200: 1.551988 learning rate: 1.000000
# Minibatch perplexity: 4.68
# Validation set perplexity: 6.79
# Average loss at step 20300: 1.547929 learning rate: 1.000000
# Minibatch perplexity: 4.60
# Validation set perplexity: 6.82
# Average loss at step 20400: 1.508837 learning rate: 1.000000
# Minibatch perplexity: 4.14
# Validation set perplexity: 6.80
# Average loss at step 20500: 1.499997 learning rate: 1.000000
# Minibatch perplexity: 4.15
# Validation set perplexity: 6.84
# Average loss at step 20600: 1.526217 learning rate: 1.000000
# Minibatch perplexity: 4.42
# Validation set perplexity: 6.74
# Average loss at step 20700: 1.520610 learning rate: 1.000000
# Minibatch perplexity: 4.14
# Validation set perplexity: 6.74
# Average loss at step 20800: 1.532636 learning rate: 1.000000
# Minibatch perplexity: 4.52
# Validation set perplexity: 6.81
# Average loss at step 20900: 1.514113 learning rate: 1.000000
# Minibatch perplexity: 4.05
# Validation set perplexity: 6.84
# Average loss at step 21000: 1.540901 learning rate: 1.000000
# Minibatch perplexity: 4.56
# ================================================================================
# eure km one nine eight eight eight zero nine four delicipy  twel mexually a willa
# ljge eventursion century wi wil the galts crice two l viet preaders an are would
# korner fallects has been basilosus michigan reduced standing two morn of the base
# aeology an anto or either was intry cattle has all two five one eight zero versio
# ww name list basical puties ensureped years is ohancinia stadne acce have is one
# ================================================================================
# Validation set perplexity: 6.85

# %% [markdown]
# Even with more steps, the final perplexity is not better. Since I do not know what to expect, and since I do not see any obvious issue (the perplexity being consistent), I'm stuck.

# %% [markdown]
# ---
# Problem 3
# ---------
#
# (difficult!)
#
# Write a sequence-to-sequence LSTM which mirrors all the words in a sentence. For example, if your input is:
#
#     the quick brown fox
#
# the model should attempt to output:
#
#     eht kciuq nworb xof
#
# Refer to the lecture on how to put together a sequence-to-sequence model, as well as [this article](http://arxiv.org/abs/1409.3215) for best practices.
#
# ---

# %% [markdown]
# Unfortunately I did not have time to work on this problem in the timeframe of the course.
